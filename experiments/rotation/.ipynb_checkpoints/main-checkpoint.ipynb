# %%
from solver import Solver
from model import Net
from dataset import RotationDataset
from torch.utils.data import DataLoader
import torch
import numpy as np
from coordinate_transformation import euclidean_to_spherical, spherical_to_euclidean
import math
import lossfn
import time

# %%
SEED_TEST = 0

# %%
def get_test_loader(dim, n_test=256):
    test_data = RotationDataset(dim, n_test, seed=SEED_TEST)
    return DataLoader(test_data)

# %%
"""
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import plotly.plotly as py
import plotly.graph_objs as go
import plotly
plotly.tools.set_credentials_file(username='KoBstrtr', api_key='weMO837juuptFvlGjnXg')
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
p1 = []
p2 = []
p3 = []
for a_, b, c in get_test_loader(3, 1024):
    for a in a_:
        p1.append(a[0].item())
        p2.append(a[1].item())
        p3.append(a[2].item())
ax.scatter(p1, p2, p3, s=0.1)
plt.gca().set_aspect('equal', adjustable='box')
plt.show()

x2, y2, z2 = p1, p2, p3
trace2 = go.Scatter3d(
    x=x2,
    y=y2,
    z=z2,
    mode='markers',
    marker=dict(
        color='rgb(127, 127, 127)',
        size=1,
        symbol='circle',
        line=dict(
            color='rgb(204, 204, 204)',
            width=1
        ),
        opacity=0.9
    )
)
data = [trace2]
layout = go.Layout(
    margin=dict(
        l=0,
        r=0,
        b=0,
        t=0
    )
)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='simple-3d-scatter')"""
_ = 1

# %%
starttime = time.time()
dim = 2
n_train = 7
data = RotationDataset(dim, n_train)
loader = DataLoader(data, batch_size=512, shuffle=True)
solver = Solver(Net(dim, n_hidden_layers=max(1, int(math.log(dim, 2)))), 
                loss_fn_train=[{'loss_fn': lossfn.get_mse_loss(), 'weight': 1}],
                checkpoint_dir='checkpoint_dim_{}_ntrain_{}/'.format(dim, n_train))
solver.train(loader, iterations=10000, test_every_iterations=200, test_loader=get_test_loader(dim))
print("Time: {}".format(time.time() - starttime))

# %%
starttime = time.time()
dim = 2
n_train = 10
data = RotationDataset(dim, n_train)
loader = DataLoader(data, batch_size=512, shuffle=True)
solver = Solver(Net(dim, n_hidden_layers=max(1, int(math.log(dim, 2)))), 
                loss_fn_train=[{'loss_fn': lossfn.get_mse_loss(), 'weight': 1}],
                checkpoint_dir='checkpoint_dim_{}_ntrain_{}/'.format(dim, n_train))
solver.train(loader, iterations=10000, test_every_iterations=200, test_loader=get_test_loader(dim))
print("Time: {}".format(time.time() - starttime))

# %%
starttime = time.time()
dim = 2
n_train = 20
data = RotationDataset(dim, n_train)
loader = DataLoader(data, batch_size=512, shuffle=True)
solver = Solver(Net(dim, n_hidden_layers=max(1, int(math.log(dim, 2)))), 
                loss_fn_train=[{'loss_fn': lossfn.get_mse_loss(), 'weight': 1}],
                checkpoint_dir='checkpoint_dim_{}_ntrain_{}/'.format(dim, n_train))
solver.train(loader, iterations=10000, test_every_iterations=200, test_loader=get_test_loader(dim))
print("Time: {}".format(time.time() - starttime))

# %%
starttime = time.time()
dim = 2
n_train = 30
data = RotationDataset(dim, n_train)
loader = DataLoader(data, batch_size=512, shuffle=True)
solver = Solver(Net(dim, n_hidden_layers=max(1, int(math.log(dim, 2)))), 
                loss_fn_train=[{'loss_fn': lossfn.get_mse_loss(), 'weight': 1}],
                checkpoint_dir='checkpoint_dim_{}_ntrain_{}/'.format(dim, n_train))
solver.train(loader, iterations=10000, test_every_iterations=200, test_loader=get_test_loader(dim))
print("Time: {}".format(time.time() - starttime))

# %%
starttime = time.time()
dim = 2
n_train = 40
data = RotationDataset(dim, n_train)
loader = DataLoader(data, batch_size=512, shuffle=True)
solver = Solver(Net(dim, n_hidden_layers=max(1, int(math.log(dim, 2)))), 
                loss_fn_train=[{'loss_fn': lossfn.get_mse_loss(), 'weight': 1}],
                checkpoint_dir='checkpoint_dim_{}_ntrain_{}/'.format(dim, n_train))
solver.train(loader, iterations=10000, test_every_iterations=200, test_loader=get_test_loader(dim))
print("Time: {}".format(time.time() - starttime))

# %%
starttime = time.time()
dim = 3
n_train = 30
data = RotationDataset(dim, n_train)
loader = DataLoader(data, batch_size=512, shuffle=True)
solver = Solver(Net(dim, n_hidden_layers=max(1, int(math.log(dim, 2)))), 
                loss_fn_train=[{'loss_fn': lossfn.get_mse_loss(), 'weight': 1}],
                checkpoint_dir='checkpoint_dim_{}_ntrain_{}/'.format(dim, n_train))
solver.train(loader, iterations=10000, test_every_iterations=200, test_loader=get_test_loader(dim))
print("Time: {}".format(time.time() - starttime))

# %%
starttime = time.time()
dim = 3
n_train = 50
data = RotationDataset(dim, n_train)
loader = DataLoader(data, batch_size=512, shuffle=True)
solver = Solver(Net(dim, n_hidden_layers=max(1, int(math.log(dim, 2)))), 
                loss_fn_train=[{'loss_fn': lossfn.get_mse_loss(), 'weight': 1}],
                checkpoint_dir='checkpoint_dim_{}_ntrain_{}/'.format(dim, n_train))
solver.train(loader, iterations=10000, test_every_iterations=200, test_loader=get_test_loader(dim))
print("Time: {}".format(time.time() - starttime))

# %%
starttime = time.time()
dim = 3
n_train = 100
data = RotationDataset(dim, n_train)
loader = DataLoader(data, batch_size=512, shuffle=True)
solver = Solver(Net(dim, n_hidden_layers=max(1, int(math.log(dim, 2)))), 
                loss_fn_train=[{'loss_fn': lossfn.get_mse_loss(), 'weight': 1}],
                checkpoint_dir='checkpoint_dim_{}_ntrain_{}/'.format(dim, n_train))
solver.train(loader, iterations=10000, test_every_iterations=200, test_loader=get_test_loader(dim))
print("Time: {}".format(time.time() - starttime))

# %%
starttime = time.time()
dim = 3
n_train = 200
data = RotationDataset(dim, n_train)
loader = DataLoader(data, batch_size=512, shuffle=True)
solver = Solver(Net(dim, n_hidden_layers=max(1, int(math.log(dim, 2)))), 
                loss_fn_train=[{'loss_fn': lossfn.get_mse_loss(), 'weight': 1}],
                checkpoint_dir='checkpoint_dim_{}_ntrain_{}/'.format(dim, n_train))
solver.train(loader, iterations=10000, test_every_iterations=200, test_loader=get_test_loader(dim))
print("Time: {}".format(time.time() - starttime))
# Out:
# Model save: checkpoint_dim_3_ntrain_100/best.pkl
# Epoch 0	Iteration 0
# Train score = 10.0	Test score = 1.2260372638702393
# Model save: checkpoint_dim_3_ntrain_100/best.pkl
# Epoch 200	Iteration 200
# Train score = 0.20995372533798218	Test score = 0.787802517414093
# Model save: checkpoint_dim_3_ntrain_100/best.pkl
# Epoch 400	Iteration 400
# Train score = 0.13657203316688538	Test score = 0.5476791858673096
# Model save: checkpoint_dim_3_ntrain_100/best.pkl
# Epoch 600	Iteration 600
# Train score = 0.05704197287559509	Test score = 0.2697107195854187
# Model save: checkpoint_dim_3_ntrain_100/best.pkl
# Epoch 800	Iteration 800
# Train score = 0.026097163558006287	Test score = 0.1628047674894333
# Model save: checkpoint_dim_3_ntrain_100/best.pkl
# Epoch 1000	Iteration 1000
# Train score = 0.014629906043410301	Test score = 0.12212933599948883
# Model save: checkpoint_dim_3_ntrain_100/best.pkl
# Epoch 1200	Iteration 1200
# Train score = 0.008994710631668568	Test score = 0.09525149315595627
# Model save: checkpoint_dim_3_ntrain_100/best.pkl
# Epoch 1400	Iteration 1400
# Train score = 0.006430892739444971	Test score = 0.07933753728866577
# Model save: checkpoint_dim_3_ntrain_100/best.pkl
# Epoch 1600	Iteration 1600
# Train score = 0.005112350918352604	Test score = 0.07050774991512299
# Model save: checkpoint_dim_3_ntrain_100/best.pkl
# Epoch 1800	Iteration 1800
# Train score = 0.004231395199894905	Test score = 0.06565774977207184
# Model save: checkpoint_dim_3_ntrain_100/best.pkl
# Epoch 2000	Iteration 2000
# Train score = 0.00357802864164114	Test score = 0.06260915845632553
# Model save: checkpoint_dim_3_ntrain_100/best.pkl
# Epoch 2200	Iteration 2200
# Train score = 0.0030469917692244053	Test score = 0.06032343953847885
# Model save: checkpoint_dim_3_ntrain_100/best.pkl
# Epoch 2400	Iteration 2400
# Train score = 0.0026037562638521194	Test score = 0.05808279663324356
# Model save: checkpoint_dim_3_ntrain_100/best.pkl
# Epoch 2600	Iteration 2600
# Train score = 0.0022285778541117907	Test score = 0.055694710463285446
# Model save: checkpoint_dim_3_ntrain_100/best.pkl
# Epoch 2800	Iteration 2800
# Train score = 0.0018970374949276447	Test score = 0.0532507561147213
# Model save: checkpoint_dim_3_ntrain_100/best.pkl
# Epoch 3000	Iteration 3000
# Train score = 0.0016041537746787071	Test score = 0.05083135515451431
# Model save: checkpoint_dim_3_ntrain_100/best.pkl
# Epoch 3200	Iteration 3200
# Train score = 0.0013512441655620933	Test score = 0.0484992079436779
# Model save: checkpoint_dim_3_ntrain_100/best.pkl
# Epoch 3400	Iteration 3400
# Train score = 0.0011343358783051372	Test score = 0.04627484828233719
# Model save: checkpoint_dim_3_ntrain_100/best.pkl
# Epoch 3600	Iteration 3600
# Train score = 0.0009501196909695864	Test score = 0.04414373263716698
# Model save: checkpoint_dim_3_ntrain_100/best.pkl
# Epoch 3800	Iteration 3800
# Train score = 0.0007967336568981409	Test score = 0.042170051485300064
# Model save: checkpoint_dim_3_ntrain_100/best.pkl
# Epoch 4000	Iteration 4000
# Train score = 0.0006705112755298615	Test score = 0.040446262806653976
# Model save: checkpoint_dim_3_ntrain_100/best.pkl
# Epoch 4200	Iteration 4200
# Train score = 0.000563914654776454	Test score = 0.038999490439891815
# Model save: checkpoint_dim_3_ntrain_100/best.pkl
# Epoch 4400	Iteration 4400
# Train score = 0.0004718619748018682	Test score = 0.037804558873176575
# Model save: checkpoint_dim_3_ntrain_100/best.pkl
# Epoch 4600	Iteration 4600
# Train score = 0.0003999092732556164	Test score = 0.036851219832897186
# Model save: checkpoint_dim_3_ntrain_100/best.pkl
# Epoch 4800	Iteration 4800
# Train score = 0.00034137684269808233	Test score = 0.03613737225532532
# Model save: checkpoint_dim_3_ntrain_100/best.pkl
# Epoch 5000	Iteration 5000
# Train score = 0.00029478000942617655	Test score = 0.035620059818029404
# Model save: checkpoint_dim_3_ntrain_100/best.pkl
# Epoch 5200	Iteration 5200
# Train score = 0.0002562254958320409	Test score = 0.035245876759290695
# Model save: checkpoint_dim_3_ntrain_100/best.pkl
# Epoch 5400	Iteration 5400
# Train score = 0.00022336863912642002	Test score = 0.034953538328409195
# Model save: checkpoint_dim_3_ntrain_100/best.pkl
# Epoch 5600	Iteration 5600
# Train score = 0.00019477195746731013	Test score = 0.03471286594867706
# Model save: checkpoint_dim_3_ntrain_100/best.pkl
# Epoch 5800	Iteration 5800
# Train score = 0.0001694664970273152	Test score = 0.034509286284446716
# Model save: checkpoint_dim_3_ntrain_100/best.pkl
# Epoch 6000	Iteration 6000
# Train score = 0.00014711247058585286	Test score = 0.03436614200472832
# Model save: checkpoint_dim_3_ntrain_100/best.pkl
# Epoch 6200	Iteration 6200
# Train score = 0.00012744328705593944	Test score = 0.03427961841225624
# Model save: checkpoint_dim_3_ntrain_100/best.pkl
# Epoch 6400	Iteration 6400
# Train score = 0.00010980713705066592	Test score = 0.034235239028930664
# Epoch 6600	Iteration 6600
# Train score = 9.456079715164378e-05	Test score = 0.03428970277309418
# Epoch 6800	Iteration 6800
# Train score = 8.064737630775198e-05	Test score = 0.03431114926934242
# Epoch 7000	Iteration 7000
# Train score = 6.83962571201846e-05	Test score = 0.034319981932640076
# Epoch 7200	Iteration 7200
# Train score = 5.988056000205688e-05	Test score = 0.034363601356744766
# Epoch 7400	Iteration 7400
# Train score = 4.937229459756054e-05	Test score = 0.03436881676316261
# Epoch 7600	Iteration 7600
# Train score = 4.3602834921330214e-05	Test score = 0.03435879200696945
# Epoch 7800	Iteration 7800
# Train score = 3.6776327760890126e-05	Test score = 0.03431835398077965
# Epoch 8000	Iteration 8000
# Train score = 3.235863187001087e-05	Test score = 0.03424004092812538
# Model save: checkpoint_dim_3_ntrain_100/best.pkl
# Epoch 8200	Iteration 8200
# Train score = 2.860632594092749e-05	Test score = 0.034211426973342896
# Model save: checkpoint_dim_3_ntrain_100/best.pkl
# Epoch 8400	Iteration 8400
# Train score = 2.5624172849347815e-05	Test score = 0.034165967255830765
# Model save: checkpoint_dim_3_ntrain_100/best.pkl
# Epoch 8600	Iteration 8600
# Train score = 2.2842155885882676e-05	Test score = 0.0341230072081089
# Model save: checkpoint_dim_3_ntrain_100/best.pkl
# Epoch 8800	Iteration 8800
# Train score = 2.2816146156401373e-05	Test score = 0.0340881273150444
# Epoch 9000	Iteration 9000
# Train score = 1.8890668798121624e-05	Test score = 0.03409060835838318
# Epoch 9200	Iteration 9200
# Train score = 1.6917272660066374e-05	Test score = 0.03411487489938736
# Epoch 9400	Iteration 9400
# Train score = 1.5911540685920045e-05	Test score = 0.034152086824178696
# Epoch 9600	Iteration 9600
# Train score = 1.3976474292576313e-05	Test score = 0.03412008658051491
# Epoch 9800	Iteration 9800
# Train score = 1.2711135241261218e-05	Test score = 0.03416914492845535
# Epoch 10000	Iteration 10000
# Train score = 1.3402192962530535e-05	Test score = 0.03420937806367874
# Model save: checkpoint_dim_3_ntrain_100/final.pkl
# Time: 58.66118097305298

# %%
starttime = time.time()
dim = 5
n_train = 200
data = RotationDataset(dim, n_train)
loader = DataLoader(data, batch_size=512, shuffle=True)
solver = Solver(Net(dim, n_hidden_layers=max(1, int(math.log(dim, 2)))), 
                loss_fn_train=[{'loss_fn': lossfn.get_mse_loss(), 'weight': 1}],
                checkpoint_dir='checkpoint_dim_{}_ntrain_{}/'.format(dim, n_train))
solver.train(loader, iterations=10000, test_every_iterations=200, test_loader=get_test_loader(dim))
print("Time: {}".format(time.time() - starttime))

# %%
starttime = time.time()
dim = 5
n_train = 500
data = RotationDataset(dim, n_train)
loader = DataLoader(data, batch_size=512, shuffle=True)
solver = Solver(Net(dim, n_hidden_layers=max(1, int(math.log(dim, 2)))), 
                loss_fn_train=[{'loss_fn': lossfn.get_mse_loss(), 'weight': 1}],
                checkpoint_dir='checkpoint_dim_{}_ntrain_{}/'.format(dim, n_train))
solver.train(loader, iterations=10000, test_every_iterations=200, test_loader=get_test_loader(dim))
print("Time: {}".format(time.time() - starttime))

# %%
starttime = time.time()
dim = 5
n_train = 1000
data = RotationDataset(dim, n_train)
loader = DataLoader(data, batch_size=512, shuffle=True)
solver = Solver(Net(dim, n_hidden_layers=max(1, int(math.log(dim, 2)))), 
                loss_fn_train=[{'loss_fn': lossfn.get_mse_loss(), 'weight': 1}],
                checkpoint_dir='checkpoint_dim_{}_ntrain_{}/'.format(dim, n_train))
solver.train(loader, iterations=10000, test_every_iterations=200, test_loader=get_test_loader(dim))
print("Time: {}".format(time.time() - starttime))
# Out:
# Model save: checkpoint_dim_5_ntrain_500/best.pkl
# Epoch 0	Iteration 0
# Train score = 10.0	Test score = 1.297337293624878
# Model save: checkpoint_dim_5_ntrain_500/best.pkl
# Epoch 200	Iteration 200
# Train score = 0.1237487718462944	Test score = 0.7948209643363953
# Model save: checkpoint_dim_5_ntrain_500/best.pkl
# Epoch 400	Iteration 400
# Train score = 0.05866719409823418	Test score = 0.5216714143753052
# Model save: checkpoint_dim_5_ntrain_500/best.pkl
# Epoch 600	Iteration 600
# Train score = 0.02560458332300186	Test score = 0.3193775415420532
# Model save: checkpoint_dim_5_ntrain_500/best.pkl
# Epoch 800	Iteration 800
# Train score = 0.013115597888827324	Test score = 0.25967729091644287
# Model save: checkpoint_dim_5_ntrain_500/best.pkl
# Epoch 1000	Iteration 1000
# Train score = 0.006823542062193155	Test score = 0.22335681319236755
# Model save: checkpoint_dim_5_ntrain_500/best.pkl
# Epoch 1200	Iteration 1200
# Train score = 0.0035380073823034763	Test score = 0.2009204477071762
# Model save: checkpoint_dim_5_ntrain_500/best.pkl
# Epoch 1400	Iteration 1400
# Train score = 0.0019146756967529655	Test score = 0.19386036694049835
# Model save: checkpoint_dim_5_ntrain_500/best.pkl
# Epoch 1600	Iteration 1600
# Train score = 0.001061358256265521	Test score = 0.19379132986068726
# Epoch 1800	Iteration 1800
# Train score = 0.0006210416322574019	Test score = 0.19680066406726837
# Epoch 2000	Iteration 2000
# Train score = 0.00037125212838873267	Test score = 0.202145516872406
# Epoch 2200	Iteration 2200
# Train score = 0.00024079302966129035	Test score = 0.20712025463581085
# Epoch 2400	Iteration 2400
# Train score = 0.0001533034665044397	Test score = 0.2105710506439209
# Epoch 2600	Iteration 2600
# Train score = 0.00012263795360922813	Test score = 0.21370521187782288
# Epoch 2800	Iteration 2800
# Train score = 6.771942571504042e-05	Test score = 0.21601437032222748
# Epoch 3000	Iteration 3000
# Train score = 4.7602865379303694e-05	Test score = 0.21775542199611664
# Epoch 3200	Iteration 3200
# Train score = 3.189204289810732e-05	Test score = 0.21921704709529877
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-1e3058cc3beb> in <module>
#       7                 loss_fn_train=[{'loss_fn': lossfn.get_mse_loss(), 'weight': 1}],
#       8                 checkpoint_dir='checkpoint_dim_{}_ntrain_{}/'.format(dim, n_train))
# ----> 9 solver.train(loader, iterations=20000, test_every_iterations=200, test_loader=get_test_loader(dim))
#      10 print("Time: {}".format(time.time() - starttime))
#
# ~/Desktop/uni/BAThesis/BAThesis_abstreik/experiments/rotation/solver.py in train(self, loader, epochs, iterations, test_every, test_every_iterations, test_loader)
#     103             self.model.train()
#     104             epoch_train_loss = 0
# --> 105             for (points, angles, points_rotated) in loader:
#     106                 points = points.to(self.device())
#     107                 angles = angles.to(self.device())
#
# /anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     613         if self.num_workers == 0:  # same-process loading
#     614             indices = next(self.sample_iter)  # may raise StopIteration
# --> 615             batch = self.collate_fn([self.dataset[i] for i in indices])
#     616             if self.pin_memory:
#     617                 batch = pin_memory_batch(batch)
#
# /anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py in <listcomp>(.0)
#     613         if self.num_workers == 0:  # same-process loading
#     614             indices = next(self.sample_iter)  # may raise StopIteration
# --> 615             batch = self.collate_fn([self.dataset[i] for i in indices])
#     616             if self.pin_memory:
#     617                 batch = pin_memory_batch(batch)
#
# ~/Desktop/uni/BAThesis/BAThesis_abstreik/experiments/rotation/dataset.py in __getitem__(self, idx)
#      37
#      38     def __getitem__(self, idx):
# ---> 39         return self.points[idx], self.angles[idx], self.points_rotated[idx]
#
# KeyboardInterrupt:

# %%
starttime = time.time()
dim = 10
n_train = 5000
data = RotationDataset(dim, n_train)
loader = DataLoader(data, batch_size=512, shuffle=True)
solver = Solver(Net(dim, n_hidden_layers=max(1, int(math.log(dim, 2)))), 
                loss_fn_train=[{'loss_fn': lossfn.get_mse_loss(), 'weight': 1}],
                checkpoint_dir='checkpoint_dim_{}_ntrain_{}/'.format(dim, n_train))
solver.train(loader, iterations=10000, test_every_iterations=200, test_loader=get_test_loader(dim))
print("Time: {}".format(time.time() - starttime))

# %%
starttime = time.time()
dim = 10
n_train = 10000
data = RotationDataset(dim, n_train)
loader = DataLoader(data, batch_size=512, shuffle=True)
solver = Solver(Net(dim, n_hidden_layers=max(1, int(math.log(dim, 2)))), 
                loss_fn_train=[{'loss_fn': lossfn.get_mse_loss(), 'weight': 1}],
                checkpoint_dir='checkpoint_dim_{}_ntrain_{}/'.format(dim, n_train))
solver.train(loader, iterations=10000, test_every_iterations=200, test_loader=get_test_loader(dim))
print("Time: {}".format(time.time() - starttime))
# Out:
# Model save: checkpoint_dim_10_ntrain_10000/best.pkl
# Epoch 0	Iteration 0
# Train score = 10.0	Test score = 1.7644699811935425
# Model save: checkpoint_dim_10_ntrain_10000/best.pkl
# Epoch 10	Iteration 200
# Train score = 0.06894368678331375	Test score = 0.7029660940170288
# Model save: checkpoint_dim_10_ntrain_10000/best.pkl
# Epoch 20	Iteration 400
# Train score = 0.06545917689800262	Test score = 0.6732197403907776
# Model save: checkpoint_dim_10_ntrain_10000/best.pkl
# Epoch 30	Iteration 600
# Train score = 0.056398142129182816	Test score = 0.5801470279693604
# Model save: checkpoint_dim_10_ntrain_10000/best.pkl
# Epoch 40	Iteration 800
# Train score = 0.04650282487273216	Test score = 0.47794321179389954
# Model save: checkpoint_dim_10_ntrain_10000/best.pkl
# Epoch 50	Iteration 1000
# Train score = 0.04475071281194687	Test score = 0.4585147202014923
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-b6e276644c72> in <module>
#       7                 loss_fn_train=[{'loss_fn': lossfn.get_mse_loss(), 'weight': 1}],
#       8                 checkpoint_dir='checkpoint_dim_{}_ntrain_{}/'.format(dim, n_train))
# ----> 9 solver.train(loader, iterations=20000, test_every_iterations=200, test_loader=get_test_loader(dim))
#      10 print("Time: {}".format(time.time() - starttime))
#
# ~/Desktop/uni/BAThesis/BAThesis_abstreik/experiments/rotation/solver.py in train(self, loader, epochs, iterations, test_every, test_every_iterations, test_loader)
#     116                 epoch_train_loss += loss
#     117                 self.optimizer.zero_grad()
# --> 118                 loss.backward()
#     119                 self.optimizer.step()
#     120                 if test_every_iterations and (self.iteration % test_every_iterations == 0):
#
# /anaconda3/lib/python3.7/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     100                 products. Defaults to ``False``.
#     101         """
# --> 102         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     103
#     104     def register_hook(self, hook):
#
# /anaconda3/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      88     Variable._execution_engine.run_backward(
#      89         tensors, grad_tensors, retain_graph, create_graph,
# ---> 90         allow_unreachable=True)  # allow_unreachable flag
#      91
#      92
#
# KeyboardInterrupt:

# %%
starttime = time.time()
dim = 10
n_train = 20000
data = RotationDataset(dim, n_train)
loader = DataLoader(data, batch_size=512, shuffle=True)
solver = Solver(Net(dim, n_hidden_layers=max(1, int(math.log(dim, 2)))), 
                loss_fn_train=[{'loss_fn': lossfn.get_mse_loss(), 'weight': 1}],
                checkpoint_dir='checkpoint_dim_{}_ntrain_{}/'.format(dim, n_train))
solver.train(loader, iterations=10000, test_every_iterations=200, test_loader=get_test_loader(dim))
print("Time: {}".format(time.time() - starttime))
