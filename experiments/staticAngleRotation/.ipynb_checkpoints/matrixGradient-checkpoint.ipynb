# %%
import pandas as pd

# %%
points = pd.read_csv("rotated_points.csv")

# %%
points.head()
# Out:
#          x1        y1        x2        y2
# 0 -0.545621  0.838032 -0.978391  0.206765
# 1  0.664113 -0.747632  0.998255 -0.059057
# 2  0.627280 -0.778793  0.994244 -0.107136
# 3  0.886203 -0.463297  0.954241  0.299039
# 4 -0.999402 -0.034592 -0.682224 -0.731144

# %% [markdown]
# # Training

# %%
import torch
from torch.autograd import Variable

# %%
learning_rate = 1e-1

# %%
rotation_matrix = Variable(torch.ones(2, 2), requires_grad=True)

# %%
for i in range(1000):
    print(i)
    point = torch.tensor([points["x1"][i], points["y1"][i]])
    pred = torch.mv(rotation_matrix, point)
    y = torch.tensor([points["x2"][i], points["y2"][i]])
    error_vec = pred - y
    error = sum([e ** 2 for e in error_vec])
    error.backward()
    print("Error squared norm")
    print(error.data.item())
    new_matrix = rotation_matrix.data - learning_rate * rotation_matrix.grad
    rotation_matrix = Variable(new_matrix, requires_grad=True)
# Out:
# 0
# Error squared norm
# 1.6222704648971558
# 1
# Error squared norm
# 0.6896820664405823
# 2
# Error squared norm
# 0.5291911363601685
# 3
# Error squared norm
# 0.021457388997077942
# 4
# Error squared norm
# 0.5466172695159912
# 5
# Error squared norm
# 0.15333469212055206
# 6
# Error squared norm
# 0.12059862911701202
# 7
# Error squared norm
# 0.01825694367289543
# 8
# Error squared norm
# 0.05901717394590378
# 9
# Error squared norm
# 0.6166484355926514
# 10
# Error squared norm
# 0.236092671751976
# 11
# Error squared norm
# 0.22407203912734985
# 12
# Error squared norm
# 1.055336594581604
# 13
# Error squared norm
# 0.02280077524483204
# 14
# Error squared norm
# 1.0138800144195557
# 15
# Error squared norm
# 0.005040835123509169
# 16
# Error squared norm
# 0.003335281042382121
# 17
# Error squared norm
# 0.31260114908218384
# 18
# Error squared norm
# 0.1795731633901596
# 19
# Error squared norm
# 0.33704307675361633
# 20
# Error squared norm
# 0.00012196047464385629
# 21
# ...
