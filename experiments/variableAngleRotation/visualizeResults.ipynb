# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
def visualize_train(train_result):
    plt.plot(train_result["epochs"], train_result["train_loss"], label='Training')
    plt.plot(train_result["epochs"], train_result["val_loss"], label='Validation')
    if len(train_result["test_loss"]):
        plt.plot(train_result["epochs"], train_result["test_loss"], label='Test')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend(loc='best')
    plt.show()

# %%
df = pd.read_csv("train_limited_data_results_35.csv", index_col="n_points_train_val")
df["train_result"] = df.apply(lambda row: eval(row["train_result"]), axis=1)

# %%
plt.plot(df.index, df.apply(lambda x: min(x["train_result"]["test_loss"]), axis=1))
plt.show()

# %%
plt.plot(df.index, df.apply(lambda x: x["train_result"]["test_loss"][np.argmin(x["train_result"]["val_loss"])], axis=1))
plt.show()

# %%
visualize_train(df["train_result"][8])

# %% [markdown]
# # Results for different numbers of hidden nodes

# %%
df = pd.read_csv("results_hidden_nodes.csv", index_col="n_hidden")
# Out:
# Index(['train_result'], dtype='object')

# %%
df["train_result"] = df.apply(lambda row: eval(row["train_result"]), axis=1)

# %%
plt.plot(df.index, df.apply(lambda x: min(x["train_result"]["test_loss"]), axis=1))
plt.show()

# %%
plt.plot(df.index, df.apply(lambda x: x["train_result"]["val_loss"][np.argmin(x["train_result"]["val_loss"])], axis=1))
plt.show()

# %%
plt.plot(df.index, df.apply(lambda x: min(x["train_result"]["val_loss"]), axis=1))
plt.show()

# %%
plt.plot(df.index, df.apply(lambda x: np.argmin(x["train_result"]["val_loss"]), axis=1))
plt.show()
